# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
wisc = pd.read_csv('c:/data/wisc_bc_data.csv')
wisc.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
wisc.diagnosis.value_counts()
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %%
wisc.columns
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %%
plt.scatter(range(357),'radius_mean',data=wisc[wisc.diagnosis=='B'],c='green',s=5,label='Benign')
plt.scatter(range(212),'radius_mean',data=wisc[wisc.diagnosis=='M'],c='red',s=5,label='Malignant')
plt.legend()
plt.xlabel('Index')
plt.ylabel('Radius  Mean')
plt.show()

# %%
plt.scatter(range(357),'area_mean',data=wisc[wisc.diagnosis=='B'],c='green',s=5,label='Benign')
plt.scatter(range(212),'area_mean',data=wisc[wisc.diagnosis=='M'],c='red',s=5,label='Malignant')
plt.legend()
plt.xlabel('Index')
plt.ylabel('area  Mean')
plt.show()

# %%
columns = ['radius_mean', 'texture_mean','smoothness_mean', 'compactness_mean', 'concavity_mean',
       'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean']
for c in columns:
    plt.scatter(range(357),c,data=wisc[wisc.diagnosis=='B'],c='green',s=5,label='Benign')
    plt.scatter(range(212),c,data=wisc[wisc.diagnosis=='M'],c='red',s=5,label='Malignant')
    plt.legend()
    plt.xlabel('Index')
    plt.ylabel(c)
    plt.show()

# %%
columns=['radius_worst', 'texture_worst','smoothness_worst','compactness_worst', 'concavity_worst', 'concave points_worst',
       'symmetry_worst', 'fractal_dimension_worst']
for c in columns:
    plt.scatter(range(357),c,data=wisc[wisc.diagnosis=='B'],c='green',s=5,label='Benign')
    plt.scatter(range(212),c,data=wisc[wisc.diagnosis=='M'],c='red',s=5,label='Malignant')
    plt.legend()
    plt.xlabel('Index')
    plt.ylabel(c)
    plt.show()

# %%
wisc.groupby('diagnosis').describe()["radius_mean"]
# Out:
#            count       mean       std     min     25%     50%    75%    max
# diagnosis
# B          357.0  12.146524  1.780512   6.981  11.080  12.200  13.37  17.85
# M          212.0  17.462830  3.203971  10.950  15.075  17.325  19.59  28.11

# %%
wisc.groupby('diagnosis').describe()['fractal_dimension_worst']
# Out:
#            count      mean       std      min       25%      50%       75%  \
# diagnosis
# B          357.0  0.079442  0.013804  0.05521  0.070090  0.07712  0.085410
# M          212.0  0.091530  0.021553  0.05504  0.076302  0.08760  0.102625
#
#               max
# diagnosis
# B          0.1486
# M          0.2075

# %%
wisc.groupby('diagnosis').describe()['concave points_mean']
# Out:
#            count      mean       std      min      25%      50%       75%  \
# diagnosis
# B          357.0  0.025717  0.015909  0.00000  0.01502  0.02344  0.032510
# M          212.0  0.087990  0.034374  0.02031  0.06462  0.08628  0.103175
#
#                max
# diagnosis
# B          0.08534
# M          0.20120
